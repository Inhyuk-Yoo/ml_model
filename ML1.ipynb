# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/2021_2학기/기계학습/
# Out:
# /content/gdrive/MyDrive/2021_2학기/기계학습

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/2021_2학기/기계학습

# %%
# !ls
# Out:
# ML1.ipynb

# %%
import os
import re
import io
import requests
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from zipfile import ZipFile
from tensorflow.python.framework import ops
ops.reset_default_graph()

# %%
epochs = 50
batch_size = 250
max_sequence_length = 25
rnn_size = 10
embedding_size = 50
min_word_frequency = 10
learning_rate = 0.0005
#dropout_keep_prob = tf.Variable(tf.ones(shape=[None, _num_states]), dtype=tf.float32)

# %%
# import csv
# f = open('train.csv', 'r', encoding='utf-8')
# rdr = csv.reader(f)
# for line in rdr:
#     print(line[0], line[1], line[2])
# f.close()

# %%
import functools
train_file_path = tf.keras.utils.get_file("train.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d016cf35a859> in <module>()
#       1 import functools
# ----> 2 train_file_path = tf.keras.utils.get_file("train.csv")
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     208   """
#     209   if origin is None:
# --> 210     raise ValueError('Please specify the "origin" argument (URL of the file '
#     211                      'to download).')
#     212
#
# ValueError: Please specify the "origin" argument (URL of the file to download).
